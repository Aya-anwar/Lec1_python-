# %%
#1. Create a list containing the numbers 1 to 5. Then:
#  - Append the number 6 to the list.
#  - Replace the second element with the number 10.

numbers = [1, 2, 3, 4, 5]
numbers.append(6)
numbers[1] = 10
print(numbers)
# Out:
# [1, 10, 3, 4, 5, 6]

# %%
#2. Given the list, perform the following:
#  - Access the first element in the list. 
#  - Remove the last element from the list. 
#  - Insert the string 'grape' at index 2. 

my_list = ['apple', 'banana', 'cherry', 'date']
print(my_list[0])
# Out:
# apple

# %%
my_list.pop()
# Out:
# 'date'

# %%
my_list.insert(2, 'grape')

# %%
print(my_list)
# Out:
# ['apple', 'banana', 'grape', 'cherry']

# %%
#3. Create a set . Then:
#  - Add the number 5 to the set.
#  - Try to add the number 3 to the set again. What happens? 
#  - Remove the number 2 from the set.

my_set = {1, 2, 3, 4}

# %%
my_set.add(5)

# %%
my_set.add(3)

# %%
my_set.remove(2)

# %%
print(my_set)
# Out:
# {1, 3, 4, 5}

# %%
#4. Given the set , perform the following: 
# - Check if 'green' is present in the set. 
# - Add 'yellow' to the set. 
# - Remove 'red' from the set. 

my_set = {'red', 'green', 'blue'}
print('green' in my_set)
# Out:
# True

# %%
my_set.add('yellow')

# %%
my_set.remove('red')

# %%
print(my_set)
# Out:
# {'blue', 'green', 'yellow'}

# %%
#5. Create a tuple . Then: 
#  - Access the third element of the tuple.
#  - Try to modify the second element of the tuple. What happens? 

my_tuple = (1, 2, 3, 4, 5)
print(my_tuple[2])
# Out:
# 3

# %%
my_tuple[1] = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 my_tuple[1] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %%
print(my_tuple)
# Out:
# (1, 2, 3, 4, 5)

# %%
#6. Given the tuple , perform the following: 
#  - Access the last element in the tuple. 
#  - Check if 'banana' is in the tuple.

my_tuple2 = ('apple', 'banana', 'cherry')
print(my_tuple2[-1])
# Out:
# cherry

# %%
print('banana' in my_tuple2)
# Out:
# True

# %%
print(my_tuple2)
# Out:
# ('apple', 'banana', 'cherry')

# %%
#7. Create a dictionary. Then: 
#  - Access the value associated with the key 'name'.
#  - Change the value of the key 'age' to 26.
#  - Add a new key 'job' with the value 'Engineer'.

person = {
    'name': 'John',
    'age': 25,
    'city': 'New York'
}

# %%
print(person['name'])
# Out:
# John

# %%
person['age'] = 26

# %%
person['job'] = 'Engineer'

# %%
print(person)
# Out:
# {'name': 'John', 'age': 26, 'city': 'New York', 'job': 'Engineer'}

# %%
#8. Given the dictionary, perform the following: 
#  - Access the value associated with the key 'model'. 
#  - Remove the key 'year' from the dictionary. 
#  - Add a new key 'color' with the value 'blue'.

my_dict = {
    'brand': 'Toyota',
    'model': 'Corolla',
    'year': 2019
}

# %%
print(my_dict['model'])
# Out:
# Corolla

# %%
my_dict.pop('year')
# Out:
# 2019

# %%
my_dict['color'] = 'blue'

# %%
print(my_dict)
# Out:
# {'brand': 'Toyota', 'model': 'Corolla', 'color': 'blue'}
